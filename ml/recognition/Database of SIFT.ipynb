# %%
import cv2
import numpy as np
import glob
import pickle

# %%
class SIFTDescriptor:
    def __init__(self, vector_size):
        self.vector_size = vector_size
        self.sift = cv2.xfeatures2d.SIFT_create()
    
    def describe(self, image_path):
        image = cv2.imread(image_path, cv2.COLOR_BGR2GRAY)
        try:
            kps = self.sift.detect(image, None)
            kps = sorted(kps, key=lambda x: -x.response)[:self.vector_size]
            kps, dsc = self.sift.compute(image, kps)
            dsc = dsc.flatten()

            needed_size = (self.vector_size * 128) # 128 is the size of a SIFT descriptor
            if dsc.size < needed_size:
                dsc = np.concatenate([dsc, np.zeros(needed_size - dsc.size)])
        except cv2.error as e:
            print('Error: ', e)
            return None
        
        return dsc

# %%
# read the image files
descriptor = SIFTDescriptor(32)
result = {}
for file in glob.glob("../detection/pos/*.jpg"):
    dsc = descriptor.describe(file)
    result[file] = dsc

f = open("features.pck", "wb")
f.write(pickle.dumps(result))
f.close()
# with open("features.pck", 'w') as fp:
#     pickle.dump(result, fp)

# %%
class Searcher:
    def __init__(self, index_path="features.pck"):
        self.index = pickle.loads(open(index_path, "rb").read())
    
    def search(self, query_features):
        results = {}
        
        for (k, features) in self.index.items():
            
            d = self.euclidean_distance(features, query_features)
            results[k] = d
        
        results = sorted([(v, k) for (k, v) in results.items()])
        
        return results
    
    def euclidean_distance(self, featuresA, featuresB):
        return np.linalg.norm(featuresA - featuresB)

# %%
searcher = Searcher()
query_features = descriptor.describe("watch_sample.png")
query_result = searcher.search(query_features)
print(query_result)
# Out:
# [(2796.952, '../detection/pos/175.jpg'), (2814.9202, '../detection/pos/935.jpg'), (2833.9495, '../detection/pos/63.jpg'), (2840.5967, '../detection/pos/920.jpg'), (2845.7847, '../detection/pos/635.jpg'), (2851.8318, '../detection/pos/425.jpg'), (2857.754, '../detection/pos/645.jpg'), (2864.4382, '../detection/pos/633.jpg'), (2865.100870824621, '../detection/pos/398.jpg'), (2865.7312, '../detection/pos/894.jpg'), (2867.2642, '../detection/pos/592.jpg'), (2869.5696, '../detection/pos/313.jpg'), (2875.604458196572, '../detection/pos/385.jpg'), (2883.0045091882876, '../detection/pos/723.jpg'), (2883.0768286675957, '../detection/pos/56.jpg'), (2886.322, '../detection/pos/696.jpg'), (2894.0579, '../detection/pos/597.jpg'), (2894.8096, '../detection/pos/37.jpg'), (2896.663, '../detection/pos/430.jpg'), (2897.351, '../detection/pos/482.jpg'), (2899.6396, '../detection/pos/541.jpg'), (2903.264541856288, '../detection/pos/294.jpg'), (2907.3325, '../detection/pos/678.jpg'), (2909.482600051081, '../detection/pos/949.jpg'), (2910.871, '../detection/pos/623.jpg'), (2912.499, '../detection/pos/150.jpg'), (2916.9932, '../detection/pos/11.jpg'), (2917.161634191702, '../detection/pos/599.jpg'), (2918.1604, '../detection/pos/872.jpg'), (2919.5485952455047, '../detection/pos/709.jpg'), (2922.306, '../detection/pos/380.jpg'), (2922.8665, '../detection/pos/393.jpg'), (2924.24, '../detection/pos/337.jpg'), (2926.0156, '../detection/pos/812.jpg'), (2927.6379557588743, '../detection/pos/179.jpg'), (2928.4194, '../detection/pos/129.jpg'), (2929.89965698486, '../detection/pos/628.jpg'), (2930.7527, '../detection/pos/748.jpg'), (2930.9883, '../detection/pos/584.jpg'), (2932.3604, '../detection/pos/32.jpg'), (2932.8944747467476, '../detection/pos/283.jpg'), (2936.6577, '../detection/pos/904.jpg'), (2938.8398, '../detection/pos/615.jpg'), (2941.113, '../detection/pos/248.jpg'), (2942.2843166492257, '../detection/pos/993.jpg'), (2942.4075, '../detection/pos/689.jpg'), (2942.680750608193, '../detection/pos/506.jpg'), (2942.8215, '../detection/pos/727.jpg'), (2943.0195, '../detection/pos/652.jpg'), (2944.1658, '../detection/pos/266.jpg'), (2944.8486, '../detection/pos/917.jpg'), (2944.972, '../detection/pos/7.jpg'), (2947.36458552382, '../detection/pos/955.jpg'), (2948.157390642501, '../detection/pos/122.jpg'), (2950.0464, '../detection/pos/842.jpg'), (2950.2666, '../detection/pos/423.jpg'), (2950.576, '../detection/pos/503.jpg'), (2950.576, '../detection/pos/829.jpg'), (2951.07, '../detection/pos/712.jpg'), (2951.7961, '../detection/pos/500.jpg'), (2952.201, '../detection/pos/953.jpg'), (2952.386661668827, '../detection/pos/411.jpg'), (2954.3545, '../detection/pos/99.jpg'), (2954.7102, '../detection/pos/348.jpg'), (2955.0806, '../detection/pos/515.jpg'), (2955.7603, '../detection/pos/801.jpg'), (2956.3845, '../detection/pos/33.jpg'), (2957.074, '../detection/pos/912.jpg'), (2957.0845, '../detection/pos/448.jpg'), (2958.084, '../detection/pos/196.jpg'), (2959.9438, '../detection/pos/427.jpg'), (2961.0833, '../detection/pos/125.jpg'), (2961.3071, '../detection/pos/227.jpg'), (2962.3472, '../detection/pos/44.jpg'), (2963.6406, '../detection/pos/956.jpg'), (2963.7329501829277, '../detection/pos/23.jpg'), (2964.0315, '../detection/pos/740.jpg'), (2964.6199, '../detection/pos/312.jpg'), (2964.7573, '../detection/pos/173.jpg'), (2965.0515, '../detection/pos/967.jpg'), (2965.207412644181, '../detection/pos/816.jpg'), (2965.538, '../detection/pos/285.jpg'), (2965.5446380049652, '../detection/pos/602.jpg'), (2966.6292, '../detection/pos/401.jpg'), (2966.941, '../detection/pos/647.jpg'), (2967.3062, '../detection/pos/715.jpg'), (2967.457329095062, '../detection/pos/558.jpg'), (2967.8792, '../detection/pos/847.jpg'), (2968.6138, '../detection/pos/636.jpg'), (2969.3918, '../detection/pos/60.jpg'), (2969.8154, '../detection/pos/821.jpg'), (2972.132063014697, '../detection/pos/166.jpg'), (2973.135718395647, '../detection/pos/451.jpg'), (2973.2861, '../detection/pos/296.jpg ...
